# %%
import sys
sys.path.append('..')
from utils import get_mongo_client, test_mongo_client, get_customers_database_infos, get_all_database_names
from bson.timestamp import Timestamp
from datetime import datetime
import pandas as pd
import random
import numpy as np
from pathlib import Path

client_local = get_mongo_client("local")
client_backup = get_mongo_client("backup")
client_prod = get_mongo_client("production")
test_mongo_client(client_local)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# get the list of customer databases
# for each c database get:

# %%
# end result
# table:
# | customer_name | db_name | space | license model | users_limit | total_users | restricted_users |
# | |

# %%
infos = get_customers_database_infos(client_local)

df_infos = pd.DataFrame(infos)
sel_col = ["name", "dbName", "hostnames", "licenseModel", "licensePeriods", "renewalDate", "accountsLimit"]
df_infos = df_infos[sel_col]
df_infos = df_infos.rename(columns={
    'name': 'customer_name', 
    'dbName': 'db_name',
    'hostnames': 'host_name',
    'licenseModel': 'license_model',
    'licensePeriods': 'license_periods',
    'renewalDate': 'renewal_date',
    'accountsLimit': 'user_limit'
})
# hostnames is the ID pf df_infos

# %%
df_infos
# Out:
#                customer_name                            db_name  \
# 0                       afpa                      org_afpa-beta
# 1            alliance-emploi                org_alliance-emploi
# 2                 anfh-corse                     org_anfh-corse
# 3              anfh-bretagne                  org_anfh-bretagne
# 4                     Apside                         org_apside
# ..                       ...                                ...
# 172     Test | SUP'EXPERTISE  sandbox_org_academie_supexpertise
# 173                 Voltaïca                       org_voltaica
# 174              LegalVision                    org_legalvision
# 175            Ecole Vendôme                  org_ecole_vendome
# 176  Serenity Coach Institut          org_serenitycoachinstitut
#
#                             host_name license_model  \
# 0                afpa-beta.didask.com      accounts
# 1          alliance-emploi.didask.com      accounts
# 2               anfh-corse.didask.com      accounts
# 3            anfh-bretagne.didask.com      accounts
# 4              apside-beta.didask.com      accounts
# ..                                ...           ...
# 172      test.supexpertise.didask.com      accounts
# 173               voltaica.didask.com      accounts
# 174            legalvision.didask.com      accounts
# 175          ecole-vendome.didask.com      accounts
# 176  serenitycoachinstitut.didask.com      accounts
#
#                                        license_periods renewal_date  \
# 0                                                   []          NaT
# 1                                                   []          NaT
# 2                                                   []          NaT
# 3                                                   []          NaT
# 4    [{'start': 2023-11-29 23:00:00, 'end': 2024-11...          NaT
# ..                                                 ...          ...
# 172                                                 []          NaT
# 173                                                NaN          NaT
# 174                                                NaN          NaT
# 175                                                NaN          NaT
# 176                                                NaN          NaT
#
#      user_limit
# 0           8.0
# 1         250.0
# 2         250.0
# 3           NaN
# 4          50.0
# ..          ...
# 172      3000.0
# 173         0.0
# 174         0.0
# 175       100.0
# 176       300.0
#
# [177 rows x 7 columns]

# %%
#client = client_local
client = client_backup
#client= client_prod

user_data = []

for i in range(0, len(df_infos)):
    customer_name = df_infos.iloc[i]["customer_name"]
    db_name = df_infos.iloc[i]["db_name"]
    hostname = df_infos.iloc[i]["host_name"]
    account_limit = df_infos.iloc[i]["user_limit"]

    db = client[db_name]
    user_collection = db['user']

    #print(f'customer: {customer_name}')
    #print(f'hostname: {hostname}')
    #print(f'account limit: {account_limit}')
    #print('---')

    for user in user_collection.find({}, {'isStandard': 1, 'disabledDate': 1, '_id': 0}):
        user["host_name"] = hostname
        for c in ['isStandard', 'disabledDate']:
            user[c] = user.get(c, None)
        user_data.append(user)

df_user = pd.DataFrame(user_data)
filtered_df = df_user[df_user['disabledDate'].isna()]

def aggregate_data(group):
    nb_users_total = len(group)
    nb_users_active = group['isStandard'].fillna(True).sum()
    nb_users_restricted = (~group["isStandard"].fillna(True)).sum()
    return pd.Series({
        'nb_users_total': nb_users_total,
        'nb_users_active': nb_users_active,
        'nb_users_restricted': nb_users_restricted
    })

# %%
df_user_group = filtered_df.groupby("host_name").apply(aggregate_data).reset_index()
df_user_group
# Out:
#                             host_name  nb_users_total  nb_users_active  \
# 0    academie-supexpertise.didask.com            1208             1160
# 1                adonnante.didask.com               7                7
# 2                afpa-beta.didask.com              40               27
# 3           afpa-formation.didask.com              20               18
# 4             afpa-sandbox.didask.com               6                4
# ..                                ...             ...              ...
# 172               voltaica.didask.com               2                2
# 173           votre-espace.didask.com              74               68
# 174                 wisper.didask.com              41               38
# 175                   yeap.didask.com             300              296
# 176              zup-de-co.didask.com              23               19
#
#      nb_users_restricted
# 0                     48
# 1                      0
# 2                     13
# 3                      2
# 4                      2
# ..                   ...
# 172                    0
# 173                    6
# 174                    3
# 175                    4
# 176                    4
#
# [177 rows x 4 columns]

# %%
df_res = df_infos.merge(df_user_group, how='left', on='host_name')
df_res = df_res.sort_values('nb_users_restricted', ascending=False).reset_index(drop=True)
df_res['user_limit'] = df_res['user_limit'].replace({0: np.nan})
df_res['user_limit'] = df_res['user_limit'].astype('Int64')
df_res['license_periods'] = df_res['license_periods'].apply(lambda x: np.nan if x == [] else x)
df_res['nb_over_limit'] = df_res['nb_users_total'] - df_res['user_limit']

# %%
df_res = df_res.sort_values("nb_over_limit", ascending=False)

# %%
missing_user_limit = df_res["user_limit"].isna().sum()
print(missing_user_limit)

missing_license_period = df_res["license_periods"].isna().sum()
print(missing_license_period)
# Out:
# 50
# 145

# %%
## ~177 clients
## 50 missing info user limit
## 35 missing info on license period

# %%
df_res['is_over_limit'] = df_res["nb_over_limit"] > 0
df_res['is_over_limit_because_restricted'] = (df_res['is_over_limit'] & (df_res['nb_users_restricted'] >= df_res['nb_over_limit']))
df_res['is_missing_limit'] = df_res["user_limit"].isna()

# set to False when user_limit is not available
df_res['is_over_limit'] = df_res['is_over_limit'].fillna(False)
df_res['is_over_limit_because_restricted'] = df_res['is_over_limit_because_restricted'].fillna(False)

# %%
nb_customers = len(df_res)
nb_over_limit = df_res["is_over_limit"].sum()
nb_over_limit_because_restricted = df_res['is_over_limit_because_restricted'].sum()
nb_missing_limit = df_res['is_missing_limit'].sum()

# %%
print(f'nb customers: {nb_customers}')
print(f'nb over limit: {nb_over_limit}')
print(f'nb over limit because of restricted users: {nb_over_limit_because_restricted}')
print(f'nb missing limit: {nb_missing_limit}')
# Out:
# nb customers: 177
# nb over limit: 15
# nb over limit because of restricted users: 5
# nb missing limit: 50

# %%
def highlight_rows(dataframe, conditions):
    """
    Apply multiple highlighting conditions to a DataFrame.
    
    :param dataframe: pandas DataFrame
    :param conditions: List of tuples, each containing the column, condition function, and color
    :return: Styled DataFrame
    """
    def highlight(row):
        styles = [''] * len(row)  # Default style (no background color)
        for column, condition, color in conditions:
            if condition(row[column]):
                styles = [f'background-color: {color}; color: black' for _ in row]
        return styles

    styled_df = dataframe.style.apply(highlight, axis=1)
    return styled_df

# %%
conditions = [
    ('is_over_limit', lambda val: val, '#FFB266'),
    ('is_over_limit_because_restricted', lambda val: val, '#FF9999'),
    ('is_missing_limit', lambda val: val, '#FFFF99')
]

# %%
styled_df = highlight_rows(df_res, conditions)
styled_df
# Out:
# <style type="text/css">
# #T_77aa0_row0_col0, #T_77aa0_row0_col1, #T_77aa0_row0_col2, #T_77aa0_row0_col3, #T_77aa0_row0_col4, #T_77aa0_row0_col5, #T_77aa0_row0_col6, #T_77aa0_row0_col7, #T_77aa0_row0_col8, #T_77aa0_row0_col9, #T_77aa0_row0_col10, #T_77aa0_row0_col11, #T_77aa0_row0_col12, #T_77aa0_row0_col13, #T_77aa0_row3_col0, #T_77aa0_row3_col1, #T_77aa0_row3_col2, #T_77aa0_row3_col3, #T_77aa0_row3_col4, #T_77aa0_row3_col5, #T_77aa0_row3_col6, #T_77aa0_row3_col7, #T_77aa0_row3_col8, #T_77aa0_row3_col9, #T_77aa0_row3_col10, #T_77aa0_row3_col11, #T_77aa0_row3_col12, #T_77aa0_row3_col13, #T_77aa0_row4_col0, #T_77aa0_row4_col1, #T_77aa0_row4_col2, #T_77aa0_row4_col3, #T_77aa0_row4_col4, #T_77aa0_row4_col5, #T_77aa0_row4_col6, #T_77aa0_row4_col7, #T_77aa0_row4_col8, #T_77aa0_row4_col9, #T_77aa0_row4_col10, #T_77aa0_row4_col11, #T_77aa0_row4_col12, #T_77aa0_row4_col13, #T_77aa0_row5_col0, #T_77aa0_row5_col1, #T_77aa0_row5_col2, #T_77aa0_row5_col3, #T_77aa0_row5_col4, #T_77aa0_row5_col5, #T_77aa0_row5_col6, #T_77aa0_row5_col7, #T_77aa0_row5_col8, #T_77aa0_row5_col9, #T_77aa0_row5_col10, #T_77aa0_row5_col11, #T_77aa0_row5_col12, #T_77aa0_row5_col13, #T_77aa0_row6_col0, #T_77aa0_row6_col1, #T_77aa0_row6_col2, #T_77aa0_row6_col3, #T_77aa0_row6_col4, #T_77aa0_row6_col5, #T_77aa0_row6_col6, #T_77aa0_row6_col7, #T_77aa0_row6_col8, #T_77aa0_row6_col9, #T_77aa0_row6_col10, #T_77aa0_row6_col11, #T_77aa0_row6_col12, #T_77aa0_row6_col13, #T_77aa0_row8_col0, #T_77aa0_row8_col1, #T_77aa0_row8_col2, #T_77aa0_row8_col3, #T_77aa0_row8_col4, #T_77aa0_row8_col5, #T_77aa0_row8_col6, #T_77aa0_row8_col7, #T_77aa0_row8_col8, #T_77aa0_row8_col9, #T_77aa0_row8_col10, #T_77aa0_row8_col11, #T_77aa0_row8_col12, #T_77aa0_row8_col13, #T_77aa0_row9_col0, #T_77aa0_row9_col1, #T_77aa0_row9_col2, #T_77aa0_row9_col3, #T_77aa0_row9_col4, #T_77aa0_row9_col5, #T_77aa0_row9_col6, #T_77aa0_row9_col7, #T_77aa0_row9_col8, #T_77aa0_row9_col9, #T_77aa0_row9_col10, #T_77aa0_row9_col11, #T_77aa0_row9_col12, #T_77aa0_row9_col13, #T_77aa0_row10_col0, #T_77aa0_row10_col1, #T_77aa0_row10_col2, #T_77aa0_row10_col3, #T_77aa0_row10_col4, #T_77aa0_row10_col5, #T_77aa0_row10_col6, #T_77aa0_row10_col7, #T_77aa0_row10_col8, #T_77aa0_row10_col9, #T_77aa0_row10_col10, #T_77aa0_row10_col11, #T_77aa0_row10_col12, #T_77aa0_row10_col13, #T_77aa0_row12_col0, #T_77aa0_row12_col1, #T_77aa0_row12_col2, #T_77aa0_row12_col3, #T_77aa0_row12_col4, #T_77aa0_row12_col5, #T_77aa0_row12_col6, #T_77aa0_row12_col7, #T_77aa0_row12_col8, #T_77aa0_row12_col9, #T_77aa0_row12_col10, #T_77aa0_row12_col11, #T_77aa0_row12_col12, #T_77aa0_row12_col13, #T_77aa0_row14_col0, #T_77aa0_row14_col1, #T_77aa0_row14_col2, #T_77aa0_row14_col3, #T_77aa0_row14_col4, #T_77aa0_row14_col5, #T_77aa0_row14_col6, #T_77aa0_row14_col7, #T_77aa0_row14_col8, #T_77aa0_row14_col9, #T_77aa0_row14_col10, #T_77aa0_row14_col11, #T_77aa0_row14_col12, #T_77aa0_row14_col13 {
#   background-color: #FFB266;
#   color: black;
# }
# #T_77aa0_row1_col0, #T_77aa0_row1_col1, #T_77aa0_row1_col2, #T_77aa0_row1_col3, #T_77aa0_row1_col4, #T_77aa0_row1_col5, #T_77aa0_row1_col6, #T_77aa0_row1_col7, #T_77aa0_row1_col8, #T_77aa0_row1_col9, #T_77aa0_row1_col10, #T_77aa0_row1_col11, #T_77aa0_row1_col12, #T_77aa0_row1_col13, #T_77aa0_row2_col0, #T_77aa0_row2_col1, #T_77aa0_row2_col2, #T_77aa0_row2_col3, #T_77aa0_row2_col4, #T_77aa0_row2_col5, #T_77aa0_row2_col6, #T_77aa0_row2_col7, #T_77aa0_row2_col8, #T_77aa0_row2_col9, #T_77aa0_row2_col10, #T_77aa0_row2_col11, #T_77aa0_row2_col12, #T_77aa0_row2_col13, #T_77aa0_row7_col0, #T_77aa0_row7_col1, #T_77aa0_row7_col2, #T_77aa0_row7_col3, #T_77aa0_row7_col4, #T_77aa0_row7_col5, #T_77aa0_row7_col6, #T_77aa0_row7_col7, #T_77aa0_row7_col8, #T_77aa0_row7_col9, #T_77aa0_row7_col10, #T_77aa0_row7_col11, #T_77aa0_row7_col12, #T_77aa0_row7_col13, #T_77aa0_row11_col0, #T_77aa0_row11_col1, #T_77aa0_row11_col2, #T_77aa0_row11_col3, #T_77aa0_row11_col4, #T_77aa0_row11_col5, #T_77aa0_row11_col6, #T_77aa0_row11_col7, #T_77aa0_row11_col8, #T_77aa0_row11_col9, #T_77aa0_row11_col10, #T_77aa0_row11_col11, #T_77aa0_row11_col12, #T_77aa0_row11_col13, #T_77aa0_row13_col0, #T_77aa0_row13_col1, #T_77aa0_row13_col2, #T_77aa0_row13_col3, #T_77aa0_row13_col4, #T_77aa0_row13_col5, #T_77aa0_row13_col6, #T_77aa0_row13_col7, #T_77aa0_row13_col8, #T_77aa0_row13_col9, #T_77aa0_row13_col10, #T_77aa0_row13_col11, #T_77aa0_row13_col12, #T_77aa0_row13_col13 {
#   background-color: #FF9999;
#   color: black;
# }
# #T_77aa0_row127_col0, #T_77aa0_row127_col1, #T_77aa0_row127_col2, #T_77aa0_row127_col3, #T_77aa0_row127_col4, #T_77aa0_row127_col5, #T_77aa0_row127_col6, #T_77aa0_row127_col7, #T_77aa0_row127_col8, #T_77aa0_row127_col9, #T_77aa0_row127_col10, #T_77aa0_row127_col11, #T_77aa0_row127_col12, #T_77aa0_row127_col13, #T_77aa0_row128_col0, #T_77aa0_row128_col1, #T_77aa0_row128_col2, #T_77aa0_row128_col3, #T_77aa0_row128_col4, #T_77aa0_row128_col5, #T_77aa0_row128_col6, #T_77aa0_row128_col7, #T_77aa0_row128_col8, #T_77aa0_row128_col9, #T_77aa0_row128_col10, #T_77aa0_row128_col11, #T_77aa0_row128_col12, #T_77aa0_row128_col13, #T_77aa0_row129_col0, #T_77aa0_row129_col1, #T_77aa0_row129_col2, #T_77aa0_row129_col3, #T_77aa0_row129_col4, #T_77aa0_row129_col5, #T_77aa0_row129_col6, #T_77aa0_row129_col7, #T_77aa0_row129_col8, #T_77aa0_row129_col9, #T_77aa0_row129_col10, #T_77aa0_row129_col11, #T_77aa0_row129_col12, #T_77aa0_row129_col13, #T_77aa0_row130_col0, #T_77aa0_row130_col1, #T_77aa0_row130_col2, #T_77aa0_row130_col3, #T_77aa0_row130_col4, #T_77aa0_row130_col5, #T_77aa0_row130_col6, #T_77aa0_row130_col7, #T_77aa0_row130_col8, #T_77aa0_row130_col9, #T_77aa0_row130_col10, #T_77aa0_row130_col11, #T_77aa0_row130_col12, #T_77aa0_row130_col13, #T_77aa0_row131_col0, #T_77aa0_row131_col1, #T_77aa0_row131_col2, #T_77aa0_row131_col3, #T_77aa0_row131_col4, #T_77aa0_row131_col5, #T_77aa0_row131_col6, #T_77aa0_row131_col7, #T_77aa0_row131_col8, #T_77aa0_row131_col9, #T_77aa0_row131_col10, #T_77aa0_row131_col11, #T_77aa0_row131_col12, #T_77aa0_row131_col13, #T_77aa0_row132_col0, #T_77aa0_row132_col1, #T_77aa0_row132_col2, #T_77aa0_row132_col3, #T_77aa0_row132_col4, #T_77aa0_row132_col5, #T_77aa0_row132_col6, #T_77aa0_row132_col7, #T_77aa0_row132_col8, #T_77aa0_row132_col9, #T_77aa0_row132_col10, #T_77aa0_row132_col11, #T_77aa0_row132_col12, #T_77aa0_row132_col13, #T_77aa0_row133_col0, #T_77aa0_row133_col1, #T_77aa0_row133_col2, #T_77aa0_row133_col3, #T_77aa0_row133_col4, #T_77aa0_row133_col5, #T_77aa0_row133_col6, #T_77aa0_row133_col7, #T_77aa0_row133_col8, #T_77aa0_row133_col9, #T_77aa0_row133_col10, #T_77aa0_row133_col11, #T_77aa0_row133_col12, #T_77aa0_row133_col13, #T_77aa0_row134_col0, #T_77aa0_row134_col1, #T_77aa0_row134_col2, #T_77aa0_row134_col3, #T_77aa0_row134_col4, #T_77aa0_row134_col5, #T_77aa0_row134_col6, #T_77aa0_row134_col7, #T_77aa0_row134_col8, #T_77aa0_row134_col9, #T_77aa0_row134_col10, #T_77aa0_row134_col11, #T_77aa0_row134_col12, #T_77aa0_row134_col13, #T_77aa0_row135_col0, #T_77aa0_row135_col1, #T_77aa0_row135_col2, #T_77aa0_row135_col3, #T_77aa0_row135_col4, #T_77aa0_row135_col5, #T_77aa0_row135_col6, #T_77aa0_row135_col7, #T_77aa0_row135_col8, #T_77aa0_row135_col9, #T_77aa0_row135_col10, #T_77aa0_row135_col11, #T_77aa0_row135_col12, #T_77aa0_row135_col13, #T_77aa0_row136_col0, #T_77aa0_row136_col1, #T_77aa0_row136_col2, #T_77aa0_row136_col3, #T_77aa0_row136_col4, #T_77aa0_row136_col5, #T_77aa0_row136_col6, #T_77aa0_row136_col7, #T_77aa0_row136_col8, #T_77aa0_row136_col9, #T_77aa0_row136_col10, #T_77aa0_row136_col11, #T_77aa0_row136_col12, #T_77aa0_row136_col13, #T_77aa0_row137_col0, #T_77aa0_row137_col1, #T_77aa0_row137_col2, #T_77aa0_row137_col3, #T_77aa0_row137_col4, #T_77aa0_row137_col5, #T_77aa0_row137_col6, #T_77aa0_row137_col7, #T_77aa0_row137_col8, #T_77aa0_row137_col9, #T_77aa0_row137_col10, #T_77aa0_row137_col11, #T_77aa0_row137_col12, #T_77aa0_row137_col13, #T_77aa0_row138_col0, #T_77aa0_row138_col1, #T_77aa0_row138_col2, #T_77aa0_row138_col3, #T_77aa0_row138_col4, #T_77aa0

# %%
path_excel_output = Path('~/Desktop/nb-users-per-customer.xlsx')
name_sheet_1 = "Clients ordonnés par dépassement de licence"
name_sheet_2 = "Clients ordonnés par nombre d'utilisateurs restreints"
with pd.ExcelWriter(path_excel_output, engine='openpyxl') as writer:
    styled_df.to_excel(writer, sheet_name=name_sheet_1, index=False)
    #df_res.sort_values('nb_users_restricted', ascending=False).to_excel(writer, sheet_name=name_sheet_2, index=False)
# Out:
# /Users/selimrbd/.pyenv/versions/3.12.0/envs/pydidask/lib/python3.12/site-packages/openpyxl/workbook/child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
